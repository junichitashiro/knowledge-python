# %% [markdown]
# # パラメータチューニングの実践
#
# **07-決定木モデルの作成** で作成した決定木モデルのパラメータをチューニングする
#
# ## 対象データ
#
# ここではSIGNATEの[【練習問題】銀行の顧客ターゲティングデータ](https://signate.jp/competitions/1/data)を使用している
#
# ### train.csv（学習データ）
#
# * 説明変数：目的変数以外の全て
# * 目的変数：y（定額預金申し込み有無）
#
# ### test.csv（評価データ）
#
# * 説明変数：全て

# %% [markdown]
# ## データの準備

# %% [markdown]
# ライブラリのインポート

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# CSVデータの読み込み

# %%
train = pd.read_csv('data/customer_targeting/train.csv')
test = pd.read_csv('data/customer_targeting/test.csv')
sample = pd.read_csv('data/customer_targeting/submit_sample.csv', header=None)

# %% [markdown]
# ## 説明変数と目的変数の設定
#
# ### 学習データの説明変数を抽出する
#
# 目的変数y以外のカラムを説明変数に設定する

# %%
trainX = train.iloc[:, 0:17]

# %% [markdown]
# 学習データの目的変数を抽出する

# %%
y = train['y']

# %% [markdown]
# ### 評価データの説明変数を抽出する
#
# 全カラムを説明変数に設定する

# %%
testX = test.copy()

# %% [markdown]
# 質的データをダミー変数化する

# %%
trainX = pd.get_dummies(trainX)
testX = pd.get_dummies(testX)

# %% [markdown]
# train と test で one-hot 後の列を揃える（列ズレ防止）

# %%
testX = testX.reindex(columns=trainX.columns, fill_value=0)

# %% [markdown]
# ## モデルの準備
#
# ### モデルを表す変数を用意する
#
# * 何個も作る可能性があるため項番を付与した変数にする
# * パラメータは一旦、前回と同じにする

# %%
clf1 = DT(max_depth=2, min_samples_leaf=500)

# %% [markdown]
# ## クロスバリデーションでモデルの精度を確認する
#
# ### fit関数（説明変数、目的変数の順に指定）でモデルを作成する
#
# オプションの説明
# * cv：データ分割数（Kに相当）
# * scoring：評価尺度
# * n_jobs：並列処理をするかどうか（-1で全てのCPUコア数を使用）

# %%
cross_validate(clf1, trainX, y, cv=5, scoring='roc_auc', n_jobs=-1, return_train_score=True)
# Out:
# {'fit_time': array([0.06077909, 0.0762639 , 0.06414247, 0.06587815, 0.06274581]),
#  'score_time': array([0.00557971, 0.00614023, 0.01625299, 0.01440048, 0.00988913]),
#  'test_score': array([0.74657601, 0.76182968, 0.73117591, 0.73707281, 0.75910043]),
#  'train_score': array([0.74534692, 0.74543889, 0.75305367, 0.75162494, 0.746135  ])}

# %% [markdown]
# 以下の精度に大差がないことが確認できる
# * test_scoreで分割されたそれぞれの精度
# * train_scoreで分割されたそれぞれの精度
# * test_scoreとtrain_scoreの精度

# %% [markdown]
# ## パラメータを変えて再度実行する

# %%
clf2 = DT(max_depth=10, min_samples_leaf=500)
cross_validate(clf2, trainX, y, cv=5, scoring='roc_auc', n_jobs=-1, return_train_score=True)
# Out:
# {'fit_time': array([0.10990834, 0.11330223, 0.11458135, 0.138556  , 0.13340163]),
#  'score_time': array([0.00601268, 0.        , 0.        , 0.00699782, 0.01008534]),
#  'test_score': array([0.88264002, 0.88482571, 0.86778474, 0.89239853, 0.88343681]),
#  'train_score': array([0.88842017, 0.89038512, 0.89288003, 0.8876343 , 0.885615  ])}

# %% [markdown]
# ## グリッドサーチによるパラメータ探索
#
# * 指定したパラメータ範囲の中で最適な精度を確認する方法
# * 1つ1つパラメータを設定して精度を確かめる手間がない

# %% [markdown]
# ## モデルの準備

# %% [markdown]
# 新しく決定木モデルを表す変数を用意する

# %%
clf3 = DT()

# %% [markdown]
# 探索するパラメータ範囲を表す変数を用意する
#
# ここではmax_pedpthを2から10まで探索する

# %%
parameters = {'max_depth':[2, 3, 4, 5, 6, 7, 8, 9, 10]}

# %% [markdown]
# rangeを使った書き方

# %%
parameters = {'max_depth':list(range(2, 11))}

# %% [markdown]
# 変数の内容を確認する

# %%
parameters
# Out:
# {'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10]}

# %% [markdown]
# ## グリッドサーチとクロスバリデーションを組み合わせて最適なパラメータを探す

# %% [markdown]
# グリッドサーチの結果を変数gcvに代入し、fit関数を使って探索を実行する

# %%
gcv = GridSearchCV(clf3, parameters, cv=5, scoring='roc_auc', n_jobs=-1, return_train_score=True)
gcv.fit(trainX, y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10]},
#              return_train_score=True, scoring='roc_auc')

# %% [markdown]
# 結果を表示する

# %%
gcv.cv_results_
# Out:
# {'mean_fit_time': array([0.06616287, 0.09241853, 0.12053018, 0.13347921, 0.18016419,
#         0.19759722, 0.24362535, 0.29255514, 0.26086998]),
#  'std_fit_time': array([0.00750031, 0.02001924, 0.01160323, 0.00686234, 0.01013228,
#         0.02328425, 0.05545579, 0.04577975, 0.03588397]),
#  'mean_score_time': array([0.00784593, 0.00717335, 0.0084424 , 0.00700784, 0.00667582,
#         0.00869279, 0.01397295, 0.0107192 , 0.00783739]),
#  'std_score_time': array([0.00153658, 0.00109509, 0.0008116 , 0.0004153 , 0.00050455,
#         0.00294328, 0.00707436, 0.00198462, 0.000764  ]),
#  'param_max_depth': masked_array(data=[2, 3, 4, 5, 6, 7, 8, 9, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value=999999),
#  'params': [{'max_depth': 2},
#   {'max_depth': 3},
#   {'max_depth': 4},
#   {'max_depth': 5},
#   {'max_depth': 6},
#   {'max_depth': 7},
#   {'max_depth': 8},
#   {'max_depth': 9},
#   {'max_depth': 10}],
#  'split0_test_score': array([0.74657601, 0.82360265, 0.73033016, 0.74058989, 0.74369939,
#         0.71937343, 0.72191264, 0.71470556, 0.7036701 ]),
#  'split1_test_score': array([0.76182968, 0.82214585, 0.843183  , 0.8534447 , 0.85661633,
#         0.85851178, 0.85916227, 0.85022738, 0.83655608]),
#  'split2_test_score': array([0.73117591, 0.8075016 , 0.83351987, 0.84179917, 0.84295916,
#         0.84706232, 0.83398104, 0.82917955, 0.80844332]),
#  'split3_test_score': array([0.73707281, 0.75196604, 0.80556935, 0.81563658, 0.82971726,
#         0.85194401, 0.85189617, 0.84165716, 0.82692256]),
#  'split4_test_score': array([0.75910043, 0.83206798, 0.85796137, 0.86203561, 0.86213026,
#         0.84466109, 0.76086685, 0.79445638, 0.71831879]),
#  'mean_test_score': array([0.74715097, 0.80745683, 0.81411275, 0.82270119, 0.82702448,
#         0.82431053, 0.8055638 , 0.80604521, 0.77878217]),
#  'std_test_score': array([0.01196124, 0.02884924, 0.04524805, 0.0439301 , 0.04315629,
#         0.05268191, 0.05444696, 0.04946252, 0.0562721 ]),
#  'rank_test_score': array([9, 5, 4, 3, 1, 2, 7, 6, 8], dtype=int32),
#  'split0_train_score': array([0.74534692, 0.82168836, 0.84726425, 0.85815618, 0.86983919,
#         0.88435788, 0.9004806 , 0.91376085, 0.92611813]),
#  'split1_train_score': array([0.74543889, 0.82283293, 0.84962306, 0.86363422, 0.87428944,
#         0.88430441, 0.89732707, 0.90808259, 0.92264557]),
#  'split2_train_score': array([0.75305367, 0.82675277, 0.85308818, 0.86694448, 0.87724756,
#         0.89265157, 0.9037161 , 0.9144906 , 0.9265592 ]),
#  'split3_train_score': array([0.75162494, 0.77022786, 0.82376143, 0.83735619, 0.8541277 ,
#         0.88438751, 0.89785886, 0.90765807, 0.92078987]),
#  'split4_train_score': array([0.746135  , 0.8207291 , 0.84693949, 0.86020065, 0.87072476,
#         0.88435379, 0.89524939, 0.90742943, 0.92471711]),
#  'mean_train_score': array([0.74831988, 0.8124462 , 0.84413528, 0.85725834, 0.86924573,
#         0.88601103, 0.8989264 , 0.91028431, 0.92416598]),
#  'std_train_score': array([0.00332399, 0.02120837, 0.01042131, 0.01039261, 0.00800703,
#         0.00332038, 0.00291804, 0.00315196, 0.00217034])}

# %% [markdown]
# 結果から重要な項目だけ取り出す

# %%
train_score = gcv.cv_results_['mean_train_score']
test_score = gcv.cv_results_['mean_test_score']

# %% [markdown]
# ## 取り出した項目を可視化する
#
# ### x軸をmax_depth、y軸をaucとしてグラフを描く
#
# このモデルではmax_depthの最小値を2に設定しているのでx軸を0～9から2～10に調整する

# %% [markdown]
# * 青：モデル構築用データ
# * 橙：モデル検証用データ

# %%
plt.plot(train_score)
plt.plot(test_score)
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ['2', '3', '4', '5', '6', '7', '8', '9', '10'])
# Out:
# ([<matplotlib.axis.XTick at 0x20583b50ed0>,
#   <matplotlib.axis.XTick at 0x205853bff50>,
#   <matplotlib.axis.XTick at 0x205859338d0>,
#   <matplotlib.axis.XTick at 0x20585949ed0>,
#   <matplotlib.axis.XTick at 0x2058594c550>,
#   <matplotlib.axis.XTick at 0x205853f6250>,
#   <matplotlib.axis.XTick at 0x2058594fad0>,
#   <matplotlib.axis.XTick at 0x20585956050>,
#   <matplotlib.axis.XTick at 0x20585960710>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %% [markdown]
# ### パラメータの最適値を表示する
#
# 検証用データの精度が高く、構築用データとの乖離が少ない箇所を確認する

# %%
gcv.best_params_
# Out:
# {'max_depth': 6}

# %% [markdown]
# ## 評価データの予測
#
# ### 予測結果を変数に代入する
#
# gcvもpredict_proba関数を持っており、自動的に最適なパラメータを使ったモデルで予測される

# %% [markdown]
# 'max_depth': 6 を使った予測結果が代入される

# %%
# predict_proba の戻りを ndarray として扱い、クラス1の確率だけを取り出す
pred = np.asarray(gcv.predict_proba(testX))[:, 1]

# %% [markdown]
# ## モデルの評価
#
# ### SIGNATEで評価する形式にデータを加工する

# %% [markdown]
# sampleファイルのカラム[1]に、予測結果を代入する

# %%
sample[1] = pred

# %% [markdown]
# sampleをCSVファイルに書き出す

# %%
sample.to_csv('data/customer_targeting/output_submit2_bank.csv', index=False, header=False)

# %% [markdown]
# 書き出したファイルを[SIGNATE](https://signate.jp/competitions/1/data)に投稿して評価を確認する
