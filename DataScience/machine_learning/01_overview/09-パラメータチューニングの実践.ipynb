# %% [markdown]
# # パラメータチューニングの実践
#
# **07-決定木モデルの作成** で作成した決定木モデルのパラメータをチューニングする
#
# ## 対象データ
#
# ここではSIGNATEの[【練習問題】銀行の顧客ターゲティングデータ](https://signate.jp/competitions/1/data)を使用している
#
# ### train.csv（学習データ）
#
# * 説明変数：目的変数以外の全て
# * 目的変数：y（定額預金申し込み有無）
#
# ### test.csv（評価データ）
#
# * 説明変数：全て

# %% [markdown]
# ## データの準備

# %% [markdown]
# ライブラリのインポート

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# CSVデータの読み込み

# %%
train = pd.read_csv('data/customer_targeting/train.csv')
test = pd.read_csv('data/customer_targeting/test.csv')
sample = pd.read_csv('data/customer_targeting/submit_sample.csv', header=None)

# %% [markdown]
# ## 説明変数と目的変数の設定
#
# ### 学習データの説明変数を抽出する
#
# 目的変数y以外のカラムを説明変数に設定する

# %%
trainX = train.iloc[:, 0:17]

# %% [markdown]
# 学習データの目的変数を抽出する

# %%
y = train['y']

# %% [markdown]
# ### 評価データの説明変数を抽出する
#
# 全カラムを説明変数に設定する

# %%
testX = test.copy()

# %% [markdown]
# 質的データをダミー変数化する

# %%
trainX = pd.get_dummies(trainX)
testX = pd.get_dummies(testX)

# %% [markdown]
# train と test で one-hot 後の列を揃える（列ズレ防止）

# %%
testX = testX.reindex(columns=trainX.columns, fill_value=0)

# %% [markdown]
# ## モデルの準備
#
# ### モデルを表す変数を用意する
#
# * 何個も作る可能性があるため項番を付与した変数にする
# * パラメータは一旦、前回と同じにする

# %%
clf1 = DT(max_depth=2, min_samples_leaf=500)

# %% [markdown]
# ## クロスバリデーションでモデルの精度を確認する
#
# ### fit関数（説明変数、目的変数の順に指定）でモデルを作成する
#
# オプションの説明
# * cv：データ分割数（Kに相当）
# * scoring：評価尺度
# * n_jobs：並列処理をするかどうか（-1で全てのCPUコア数を使用）

# %%
cross_validate(clf1, trainX, y, cv=5, scoring='roc_auc', n_jobs=-1, return_train_score=True)
# Out:
# {'fit_time': array([0.04719353, 0.05366135, 0.05365849, 0.05797219, 0.0542078 ]),
#  'score_time': array([0.00949144, 0.00987363, 0.00516391, 0.00597215, 0.00529194]),
#  'test_score': array([0.74657601, 0.76182968, 0.73117591, 0.73707281, 0.75910043]),
#  'train_score': array([0.74534692, 0.74543889, 0.75305367, 0.75162494, 0.746135  ])}

# %% [markdown]
# 以下の精度に大差がないことが確認できる
# * test_scoreで分割されたそれぞれの精度
# * train_scoreで分割されたそれぞれの精度
# * test_scoreとtrain_scoreの精度

# %% [markdown]
# ## パラメータを変えて再度実行する

# %%
clf2 = DT(max_depth=10, min_samples_leaf=500)
cross_validate(clf2, trainX, y, cv=5, scoring='roc_auc', n_jobs=-1, return_train_score=True)
# Out:
# {'fit_time': array([0.10424495, 0.11040068, 0.11660409, 0.15322709, 0.15247059]),
#  'score_time': array([0.00595737, 0.00638032, 0.00490475, 0.00792956, 0.00945568]),
#  'test_score': array([0.88264002, 0.88482571, 0.86778474, 0.89239853, 0.88343681]),
#  'train_score': array([0.88842017, 0.89038512, 0.89288003, 0.8876343 , 0.885615  ])}

# %% [markdown]
# ## グリッドサーチによるパラメータ探索
#
# * 指定したパラメータ範囲の中で最適な精度を確認する方法
# * 1つ1つパラメータを設定して精度を確かめる手間がない

# %% [markdown]
# ## モデルの準備

# %% [markdown]
# 新しく決定木モデルを表す変数を用意する

# %%
clf3 = DT()

# %% [markdown]
# 探索するパラメータ範囲を表す変数を用意する
#
# ここではmax_pedpthを2から10まで探索する

# %%
parameters = {'max_depth':[2, 3, 4, 5, 6, 7, 8, 9, 10]}

# %% [markdown]
# rangeを使った書き方

# %%
parameters = {'max_depth':list(range(2, 11))}

# %% [markdown]
# 変数の内容を確認する

# %%
parameters
# Out:
# {'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10]}

# %% [markdown]
# ## グリッドサーチとクロスバリデーションを組み合わせて最適なパラメータを探す

# %% [markdown]
# グリッドサーチの結果を変数gcvに代入し、fit関数を使って探索を実行する

# %%
gcv = GridSearchCV(clf3, parameters, cv=5, scoring='roc_auc', n_jobs=-1, return_train_score=True)
gcv.fit(trainX, y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10]},
#              return_train_score=True, scoring='roc_auc')

# %% [markdown]
# 結果を表示する

# %%
gcv.cv_results_
# Out:
# {'mean_fit_time': array([0.08045244, 0.12430124, 0.16101756, 0.17103896, 0.17563515,
#         0.20515165, 0.23201818, 0.30819893, 0.22530146]),
#  'std_fit_time': array([0.01278095, 0.01668436, 0.02838733, 0.04056609, 0.02349197,
#         0.01868028, 0.03210736, 0.05278014, 0.03097239]),
#  'mean_score_time': array([0.01368799, 0.02727547, 0.00871978, 0.01504107, 0.00765843,
#         0.00814524, 0.00979195, 0.00749202, 0.00534506]),
#  'std_score_time': array([0.00516835, 0.01637269, 0.00107654, 0.01429032, 0.00077159,
#         0.00146939, 0.00251865, 0.0002749 , 0.00116003]),
#  'param_max_depth': masked_array(data=[2, 3, 4, 5, 6, 7, 8, 9, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value=999999),
#  'params': [{'max_depth': 2},
#   {'max_depth': 3},
#   {'max_depth': 4},
#   {'max_depth': 5},
#   {'max_depth': 6},
#   {'max_depth': 7},
#   {'max_depth': 8},
#   {'max_depth': 9},
#   {'max_depth': 10}],
#  'split0_test_score': array([0.74657601, 0.82360265, 0.73033016, 0.74058989, 0.74368476,
#         0.73236465, 0.73602276, 0.71784037, 0.70574864]),
#  'split1_test_score': array([0.76182968, 0.82214585, 0.843183  , 0.85330188, 0.85817584,
#         0.85744876, 0.85683688, 0.85178624, 0.84128936]),
#  'split2_test_score': array([0.73117591, 0.8075016 , 0.83351987, 0.84179917, 0.843278  ,
#         0.84638421, 0.82786261, 0.83239128, 0.80173899]),
#  'split3_test_score': array([0.73707281, 0.75196604, 0.80556935, 0.81563658, 0.82971726,
#         0.85025693, 0.85095277, 0.84406999, 0.8205931 ]),
#  'split4_test_score': array([0.75910043, 0.83206798, 0.85796137, 0.86203561, 0.86213026,
#         0.84466109, 0.83115917, 0.73037099, 0.71949607]),
#  'mean_test_score': array([0.74715097, 0.80745683, 0.81411275, 0.82267263, 0.82739723,
#         0.82622313, 0.82056684, 0.79529178, 0.77777323]),
#  'std_test_score': array([0.01196124, 0.02884924, 0.04524805, 0.04391014, 0.04340291,
#         0.04713492, 0.043708  , 0.05858454, 0.05481964]),
#  'rank_test_score': array([9, 6, 5, 3, 1, 2, 4, 7, 8], dtype=int32),
#  'split0_train_score': array([0.74534692, 0.82168836, 0.84726425, 0.85815618, 0.86983919,
#         0.88432329, 0.90048061, 0.91361733, 0.92613458]),
#  'split1_train_score': array([0.74543889, 0.82283293, 0.84962306, 0.86363422, 0.87426809,
#         0.88432372, 0.89732707, 0.90808259, 0.92264977]),
#  'split2_train_score': array([0.75305367, 0.82675277, 0.85308818, 0.86694448, 0.87724756,
#         0.89246126, 0.90365754, 0.91417604, 0.92651895]),
#  'split3_train_score': array([0.75162494, 0.77022786, 0.82376143, 0.83735619, 0.8541277 ,
#         0.88438751, 0.89785886, 0.90779444, 0.92071641]),
#  'split4_train_score': array([0.746135  , 0.8207291 , 0.84693949, 0.86020065, 0.87072476,
#         0.88435379, 0.89537661, 0.90742943, 0.92470789]),
#  'mean_train_score': array([0.74831988, 0.8124462 , 0.84413528, 0.85725834, 0.86924146,
#         0.88596991, 0.89894014, 0.91021996, 0.92414552]),
#  'std_train_score': array([0.00332399, 0.02120837, 0.01042131, 0.01039261, 0.00800435,
#         0.00324576, 0.00286694, 0.00301434, 0.00218641])}

# %% [markdown]
# 結果から重要な項目だけ取り出す

# %%
train_score = gcv.cv_results_['mean_train_score']
test_score = gcv.cv_results_['mean_test_score']

# %% [markdown]
# ## 取り出した項目を可視化する
#
# ### x軸をmax_depth、y軸をaucとしてグラフを描く
#
# このモデルではmax_depthの最小値を2に設定しているのでx軸を0～9から2～10に調整する

# %% [markdown]
# * 青：モデル構築用データ
# * 橙：モデル検証用データ

# %%
plt.plot(train_score)
plt.plot(test_score)
plt.xticks([0, 1, 2, 3, 4, 5, 6, 7, 8], ['2', '3', '4', '5', '6', '7', '8', '9', '10'])
# Out:
# ([<matplotlib.axis.XTick at 0x1d33e919160>,
#   <matplotlib.axis.XTick at 0x1d33e91e350>,
#   <matplotlib.axis.XTick at 0x1d33e91ead0>,
#   <matplotlib.axis.XTick at 0x1d33e91f250>,
#   <matplotlib.axis.XTick at 0x1d33e91f9d0>,
#   <matplotlib.axis.XTick at 0x1d33fb94190>,
#   <matplotlib.axis.XTick at 0x1d33fb94910>,
#   <matplotlib.axis.XTick at 0x1d33fb95090>,
#   <matplotlib.axis.XTick at 0x1d33fb95810>],
#  [Text(0, 0, '2'),
#   Text(1, 0, '3'),
#   Text(2, 0, '4'),
#   Text(3, 0, '5'),
#   Text(4, 0, '6'),
#   Text(5, 0, '7'),
#   Text(6, 0, '8'),
#   Text(7, 0, '9'),
#   Text(8, 0, '10')])

# %% [markdown]
# ### パラメータの最適値を表示する
#
# 検証用データの精度が高く、構築用データとの乖離が少ない箇所を確認する

# %%
gcv.best_params_
# Out:
# {'max_depth': 6}

# %% [markdown]
# ## 評価データの予測
#
# ### 予測結果を変数に代入する
#
# gcvもpredict_proba関数を持っており、自動的に最適なパラメータを使ったモデルで予測される

# %% [markdown]
# 'max_depth': 6 を使った予測結果が代入される

# %%
# predict_proba の戻りを ndarray として扱い、クラス1の確率だけを取り出す
pred = np.asarray(gcv.predict_proba(testX))[:, 1]

# %% [markdown]
# ## モデルの評価
#
# ### SIGNATEで評価する形式にデータを加工する

# %% [markdown]
# sampleファイルのカラム[1]に、予測結果を代入する

# %%
sample[1] = pred

# %% [markdown]
# sampleをCSVファイルに書き出す

# %%
sample.to_csv('data/customer_targeting/output_submit2_bank.csv', index=False, header=False)

# %% [markdown]
# 書き出したファイルを[SIGNATE](https://signate.jp/competitions/1/data)に投稿して評価を確認する
