# %% [markdown]
# # 特徴量の選択と作成
#
# ## 特徴量の選択
#
# * 特徴量が多すぎると過学習のリスクになる
# * 機械学習の精度を高めるためには重要な特徴量だけを選択する必要がある
#
# ## 特徴量選択手法
#
# ### 単変量解析
#
# * 目的変数と各説明変数を1対1で確認し取捨選択する
# * 分散分析など
#
# ### モデルベース選択
# * モデルにとっての各変数の重要度を算出し取捨選択する
# * ツリー系機械学習手法の重要度をみる
#
# ### 反復選択
# * 特徴量を増減させながらモデルを生成し良い特徴量を探索する
# * ステップワイズ法など
#
# ## 対象データ
#
# ここではSIGNATEの[【練習問題】お弁当の需要予測データ](https://signate.jp/competitions/24/data)を使用している
#
# ### train.csv（学習データ）
#
# 説明変数は新規に作成する
#
# * 説明変数：year, month
# * 目的変数：y
#
# ### test.csv（評価データ）
#
# 説明変数は新規に作成する
#
# * 説明変数：year, month

# %% [markdown]
# ## データの準備

# %% [markdown]
# ライブラリのインポート

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression as LR

# %% [markdown]
# CSVデータの読み込み

# %%
train = pd.read_csv('data/demand_forcast/train.csv')
test = pd.read_csv('data/demand_forcast/test.csv')
sample = pd.read_csv('data/demand_forcast/sample.csv', header=None)

# %% [markdown]
# ## データの確認

# %% [markdown]
# 売上の折れ線グラフを確認

# %%
train['y'].plot(figsize=(12, 4))
# Out:
# <Axes: >

# %% [markdown]
# 学習データの内容を確認

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## 新しい特徴量の追加
#
# ここでは時系列に相当する新しい特徴量を作成してみる

# %% [markdown]
# ## 新しいカラムの追加
#
# 学習データのdatetimeから年月を取り出し、新たなカラムとして追加する

# %% [markdown]
# ハイフンで分割したdatetimeの1つ目の要素を変数yearに格納

# %%
train['year'] = train['datetime'].apply(lambda x :x.split('-')[0])

# %% [markdown]
# 2つ目の要素を変数monthに格納

# %%
train['month'] = train['datetime'].apply(lambda x :x.split('-')[1])

# %% [markdown]
# 評価データにも同様の処理をする

# %%
test['year'] = test['datetime'].apply(lambda x :x.split('-')[0])
test['month'] = test['datetime'].apply(lambda x :x.split('-')[1])

# %% [markdown]
# ## データ型の変換

# %% [markdown]
# 機械学習に適したデータ型になっているか確認する

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       207 non-null    object
#  1   y              207 non-null    int64
#  2   week           207 non-null    object
#  3   soldout        207 non-null    int64
#  4   name           207 non-null    object
#  5   kcal           166 non-null    float64
#  6   remarks        21 non-null     object
#  7   event          14 non-null     object
#  8   payday         10 non-null     float64
#  9   weather        207 non-null    object
#  10  precipitation  207 non-null    object
#  11  temperature    207 non-null    float64
#  12  year           207 non-null    object
#  13  month          207 non-null    object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 22.8+ KB

# %% [markdown]
# 追加した列のデータ型をオブジェクト型から数値型に変換する

# %%
train['year'] = train['year'].astype(np.int64)
train['month'] = train['month'].astype(np.int64)
test['year'] = test['year'].astype(np.int64)
test['month'] = test['month'].astype(np.int64)

# %% [markdown]
# 変換後のデータ型を確認

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       207 non-null    object
#  1   y              207 non-null    int64
#  2   week           207 non-null    object
#  3   soldout        207 non-null    int64
#  4   name           207 non-null    object
#  5   kcal           166 non-null    float64
#  6   remarks        21 non-null     object
#  7   event          14 non-null     object
#  8   payday         10 non-null     float64
#  9   weather        207 non-null    object
#  10  precipitation  207 non-null    object
#  11  temperature    207 non-null    float64
#  12  year           207 non-null    int64
#  13  month          207 non-null    int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 22.8+ KB

# %% [markdown]
# ## ここからは通常の重回帰モデル作成と同様に進める

# %% [markdown]
# 学習データから説明変数と目的変数を抽出する

# %%
trainX = train[['year', 'month']]
y = train['y']

# %% [markdown]
# 評価データから説明変数を抽出する

# %%
testX = test[['year', 'month']]

# %% [markdown]
# ## モデルの準備
#
# ### モデルを表す変数を用意する

# %%
model = LR()

# %% [markdown]
# ## モデルの作成
#
# ### 重回帰モデルの作成

# %%
model.fit(trainX, y)
# Out:
# LinearRegression()

# %% [markdown]
# モデルの傾きを確認する

# %%
model.coef_
# Out:
# array([-104.0107109 ,   -7.41004428])

# %% [markdown]
# モデルの切片を確認する

# %%
model.intercept_
# Out:
# np.float64(209594.15656370853)

# %% [markdown]
# ## モデルを使った予測
#
# ### predict関数での予測

# %%
model.predict(testX)
# Out:
# array([42.48436184, 42.48436184, 42.48436184, 42.48436184, 42.48436184,
#        42.48436184, 42.48436184, 42.48436184, 42.48436184, 42.48436184,
#        42.48436184, 42.48436184, 42.48436184, 42.48436184, 42.48436184,
#        42.48436184, 42.48436184, 42.48436184, 42.48436184, 42.48436184,
#        42.48436184, 42.48436184, 35.07431756, 35.07431756, 35.07431756,
#        35.07431756, 35.07431756, 35.07431756, 35.07431756, 35.07431756,
#        35.07431756, 35.07431756, 35.07431756, 35.07431756, 35.07431756,
#        35.07431756, 35.07431756, 35.07431756, 35.07431756, 35.07431756])

# %% [markdown]
# predict関数を使った予測結果を変数に代入する

# %%
pred = model.predict(testX)

# %% [markdown]
# ## モデルの評価
#
# ### SIGNATEで評価する形式にデータを加工する

# %% [markdown]
# sampleファイルのカラム[1]に、予測結果を代入する

# %%
sample.head()
# Out:
#            0   1
# 0  2014-10-1  24
# 1  2014-10-2  71
# 2  2014-10-3  25
# 3  2014-10-6  32
# 4  2014-10-7  60

# %%
sample[1] = pred

# %%
sample.head()
# Out:
#            0          1
# 0  2014-10-1  42.484362
# 1  2014-10-2  42.484362
# 2  2014-10-3  42.484362
# 3  2014-10-6  42.484362
# 4  2014-10-7  42.484362

# %% [markdown]
# sampleをCSVファイルに書き出す

# %%
sample.to_csv('data/demand_forcast/output_submit3.csv', index=False, header=False)

# %% [markdown]
# 書き出したファイルを[SIGNATE](https://signate.jp/competitions/24/data)に投稿して評価を確認する

# %% [markdown]
# ## 特徴量のさらなる追加
#
# 予測値と実績値との誤差を新たな特徴量として追加する

# %% [markdown]
# 学習データで予測モデルを作成する

# %%
pred = model.predict(trainX)

# %% [markdown]
# この予測値を学習データの新しいカラムとして追加する

# %%
train['pred'] = pred

# %% [markdown]
# 学習データの販売数実績（y）と予測値（pred）の差を新しいカラム（res）として代入する

# %%
train['res'] = train['y'] - train['pred']

# %% [markdown]
# 新しいカラムに着目してデータの中身を確認する

# %%
train.sort_values(by='res')
# Out:
#        datetime    y week  soldout         name   kcal   remarks event  \
# 27   2013-12-26   80    木        0           酢豚    NaN       NaN   NaN
# 0    2013-11-18   90    月        0     厚切りイカフライ    NaN       NaN   NaN
# 81    2014-3-26   51    水        0  肉団子クリームシチュー  392.0       NaN   NaN
# 82    2014-3-27   55    木        1     ロース甘味噌焼き  315.0       NaN   NaN
# 1    2013-11-19  101    火        1      手作りヒレカツ    NaN       NaN   NaN
# ..          ...  ...  ...      ...          ...    ...       ...   ...
# 115   2014-5-16  126    金        0       ポークカレー    NaN  お楽しみメニュー  ママの会
# 135   2014-6-13  121    金        0       キーマカレー    NaN  お楽しみメニュー   NaN
# 155   2014-7-11  124    金        0       ポークカレー    NaN  お楽しみメニュー   NaN
# 196   2014-9-12  115    金        0       ポークカレー    NaN  お楽しみメニュー   NaN
# 174    2014-8-8  129    金        0       チキンカレー    NaN  お楽しみメニュー   NaN
#
#      payday weather precipitation  temperature  year  month        pred  \
# 27      NaN       曇            --          7.3  2013     12  131.674984
# 0       NaN      快晴            --         19.8  2013     11  139.085028
# 81      NaN       曇            --         18.7  2014      3   94.354672
# 82      NaN       曇           1.5         12.4  2014      3   94.354672
# 1       NaN      快晴            --         17.0  2013     11  139.085028
# ..      ...     ...           ...          ...   ...    ...         ...
# 115     NaN      快晴            --         23.8  2014      5   79.534583
# 135     NaN      晴れ            --         29.5  2014      6   72.124539
# 155     NaN      晴れ            --         33.9  2014      7   64.714495
# 196     NaN      晴れ            --         27.3  2014      9   49.894406
# 174     1.0       曇            --         31.1  2014      8   57.304450
#
#            res
# 27  -51.674984
# 0   -49.085028
# 81  -43.354672
# 82  -39.354672
# 1   -38.085028
# ..         ...
# 115  46.465417
# 135  48.875461
# 155  59.285505
# 196  65.105594
# 174  71.695550
#
# [207 rows x 16 columns]

# %% [markdown]
# ## 追加する特徴量の検討
#
# ### 予測値を大きく外している商品の傾向を読み取る
#
# * 予測より販売数の少ない商品に共通する特徴は見受けられない
# * 予測より販売数の多い商品には以下の共通点が見られる
#   * 金曜日
#   * カレー
#   * お楽しみメニュー
#
# ### 以下の項目を作成し特徴量として追加する
#
# * お楽しみメニューであるかどうかを表す項目

# %% [markdown]
# ## 関数の作成

# %% [markdown]
# 以下の関数を作る
#
# * お楽しみメニューであれば1を返す
# * そうでなければ0を返す

# %%
def fun_or_not(x):
    if x == 'お楽しみメニュー':
        return 1
    else :
        return 0

# %% [markdown]
# 作成した関数を使って新しいカラム（frun）を追加する

# %%
train['fun'] = train['remarks'].apply(lambda x :fun_or_not(x))
test['fun'] = test['remarks'].apply(lambda x :fun_or_not(x))

# %% [markdown]
# 追加後のデータを確認する

# %%
train
# Out:
#        datetime    y week  soldout          name   kcal          remarks  \
# 0    2013-11-18   90    月        0      厚切りイカフライ    NaN              NaN
# 1    2013-11-19  101    火        1       手作りヒレカツ    NaN              NaN
# 2    2013-11-20  118    水        0    白身魚唐揚げ野菜あん    NaN              NaN
# 3    2013-11-21  120    木        1        若鶏ピリ辛焼    NaN              NaN
# 4    2013-11-22  130    金        1      ビッグメンチカツ    NaN              NaN
# ..          ...  ...  ...      ...           ...    ...              ...
# 202   2014-9-24   59    水        1   白身魚のマスタード焼き  408.0              NaN
# 203   2014-9-25   50    木        0       牛カルビ焼き肉  394.0              NaN
# 204   2014-9-26   45    金        0      ランチビュッフェ    NaN  スペシャルメニュー（800円）
# 205   2014-9-29   56    月        1      豚肉と玉子の炒め  404.0              NaN
# 206   2014-9-30   40    火        0  鶏肉とカシューナッツ炒め  398.0              NaN
#
#              event  payday weather precipitation  temperature  year  month  \
# 0              NaN     NaN      快晴            --         19.8  2013     11
# 1              NaN     NaN      快晴            --         17.0  2013     11
# 2              NaN     NaN      快晴            --         15.5  2013     11
# 3              NaN     NaN      快晴            --         15.2  2013     11
# 4              NaN     NaN      快晴            --         16.1  2013     11
# ..             ...     ...     ...           ...          ...   ...    ...
# 202            NaN     NaN       曇             0         24.8  2014      9
# 203            NaN     NaN       曇             0         25.4  2014      9
# 204  キャリアアップ支援セミナー     NaN      晴れ            --         27.1  2014      9
# 205            NaN     NaN      快晴            --         26.6  2014      9
# 206            NaN     NaN      快晴            --         28.1  2014      9
#
#            pred        res  fun
# 0    139.085028 -49.085028    0
# 1    139.085028 -38.085028    0
# 2    139.085028 -21.085028    0
# 3    139.085028 -19.085028    0
# 4    139.085028  -9.085028    0
# ..          ...        ...  ...
# 202   49.894406   9.105594    0
# 203   49.894406   0.105594    0
# 204   49.894406  -4.894406    0
# 205   49.894406   6.105594    0
# 206   49.894406  -9.894406    0
#
# [207 rows x 17 columns]

# %%
test
# Out:
#       datetime week  soldout            name   kcal         remarks  \
# 0    2014-10-1    水        1           メンチカツ  420.0             NaN
# 1    2014-10-2    木        0       バーベキューチキン  415.0             NaN
# 2    2014-10-3    金        0      豚肉のマスタード焼き  405.0             NaN
# 3    2014-10-6    月        1            麻婆春雨  400.0             NaN
# 4    2014-10-7    火        0        厚揚げ肉みそ炒め  430.0             NaN
# 5    2014-10-8    水        0    完熟トマトのホットカレー  420.0             NaN
# 6    2014-10-9    木        0          豚キムチ炒め  435.0             NaN
# 7   2014-10-10    金        0          ポークカレー    NaN        お楽しみメニュー
# 8   2014-10-14    火        0         若鶏梅肉包揚げ  408.0             NaN
# 9   2014-10-15    水        1         ミックスグリル  450.0    料理長のこだわりメニュー
# 10  2014-10-16    木        0      豚肉と白菜の中華炒め  400.0             NaN
# 11  2014-10-17    金        0            ヒレカツ  415.0             NaN
# 12  2014-10-20    月        1             豚柳川  426.0             NaN
# 13  2014-10-21    火        0         ポーク生姜焼き  410.0             NaN
# 14  2014-10-22    水        1            麻婆豆腐  415.0             NaN
# 15  2014-10-23    木        1       ビーフストロガノフ  428.0             NaN
# 16  2014-10-24    金        0            唐揚げ丼    NaN        お楽しみメニュー
# 17  2014-10-27    月        1           マス塩焼き  407.0             NaN
# 18  2014-10-28    火        1        チンジャオロース  425.0             NaN
# 19  2014-10-29    水        0         厚切イカフライ  430.0             NaN
# 20  2014-10-30    木        0     鶏肉と野菜の黒胡椒炒め  426.0             NaN
# 21  2014-10-31    金        0             八宝菜  436.0             NaN
# 22   2014-11-4    火        0         豚肉の生姜焼き  440.0             NaN
# 23   2014-11-5    水        1           ハンバーグ  425.0             NaN
# 24   2014-11-6    木        1    彩り野菜と鶏肉の黒酢あん  410.0             NaN
# 25   2014-11-7    金        0          ポークカレー    NaN        お楽しみメニュー
# 26  2014-11-10    月        0             親子煮  412.0             NaN
# 27  2014-11-11    火        0   ポークのバーベキューソテー  426.0             NaN
# 28  2014-11-12    水        0          鶏肉の唐揚げ  418.0             NaN
# 29  2014-11-13    木        1         白身魚味噌焼き  396.0  近隣に飲食店複合ビルオープン
# 30  2014-11-14    金        1      エビフライ・エビカツ  427.0             NaN
# 31  2014-11-17    月        1      野菜ごろごろシチュー  433.0             NaN
# 32  2014-11-18    火        1            麻婆豆腐  409.0             NaN
# 33  2014-11-19    水        0  ベルギー風チキンのクリーム煮  430.0    料理長のこだわりメニュー
# 34  2014-11-20    木        1          スタミナ炒め  421.0             NaN
# 35  2014-11-21    金        0           ロコモコ丼    NaN        お楽しみメニュー
# 36  2014-11-25    火        1     なすと挽肉のはさみ揚げ  460.0             NaN
# 37  2014-11-26    水        1         鶏肉の治部煮風  415.0             NaN
# 38  2014-11-27    木        0             牛丼風  420.0             NaN
# 39  2014-11-28    金        0    鶏肉のスイートチリソース  416.0             NaN
#
#             event  payday weather precipitation  temperature  year  month  fun
# 0             NaN     NaN       雨             0         20.2  2014     10    0
# 1             NaN     NaN       曇            --         23.9  2014     10    0
# 2             NaN     NaN      晴れ            --         28.7  2014     10    0
# 3             NaN     NaN       雨           0.5         21.5  2014     10    0
# 4             NaN     NaN      晴れ            --         22.1  2014     10    0
# 5             NaN     NaN      晴れ            --         23.3  2014     10    0
# 6   キャリアアップ支援セミナー     NaN       曇            --         22.5  2014     10    0
# 7             NaN     1.0      薄曇            --         26.1  2014     10    1
# 8             NaN     NaN      快晴            --         26.8  2014     10    0
# 9             NaN     NaN       雨           1.5         15.6  2014     10    0
# 10            NaN     NaN      晴れ            --         18.6  2014     10    0
# 11           ママの会     NaN      快晴            --         23.0  2014     10    0
# 12            NaN     NaN      薄曇            --         23.9  2014     10    0
# 13            NaN     NaN       雨             0         20.2  2014     10    0
# 14            NaN     NaN       雨             0         15.5  2014     10    0
# 15            NaN     NaN       雨           0.5         14.7  2014     10    0
# 16            NaN     NaN      快晴            --         18.7  2014     10    1
# 17            NaN     NaN      薄曇            --         22.7  2014     10    0
# 18            NaN     NaN      快晴            --         19.1  2014     10    0
# 19            NaN     NaN      快晴            --         19.6  2014     10    0
# 20            NaN     NaN      晴れ            --         19.6  2014     10    0
# 21            NaN     NaN       曇            --         18.8  2014     10    0
# 22            NaN     NaN      晴れ            --         18.9  2014     11    0
# 23            NaN     NaN       曇            --         16.0  2014     11    0
# 24            NaN     NaN       曇            --         19.2  2014     11    0
# 25            NaN     NaN      晴れ            --         20.1  2014     11    1
# 26            NaN     1.0      快晴            --         21.2  2014     11    0
# 27            NaN     NaN       曇             0         14.7  2014     11    0
# 28            NaN     NaN       曇            --         14.4  2014     11    0
# 29  キャリアアップ支援セミナー     NaN      快晴            --         19.5  2014     11    0
# 30            NaN     NaN      快晴            --         15.8  2014     11    0
# 31            NaN     NaN      薄曇            --         14.3  2014     11    0
# 32            NaN     NaN      快晴            --         16.1  2014     11    0
# 33            NaN     NaN      快晴            --         14.9  2014     11    0
# 34            NaN     NaN       曇            --         10.5  2014     11    0
# 35            NaN     NaN      快晴            --         14.9  2014     11    1
# 36            NaN     NaN       雨           1.5         11.4  2014     11    0
# 37            NaN     NaN       雨             1          9.2  2014     11    0
# 38            NaN     NaN      快晴            --         15.1  2014     11    0
# 39            NaN     NaN       曇            --         15.3  2014     11    0

# %% [markdown]
# ## 重回帰モデルの再作成

# %% [markdown]
# 追加カラムを含む特定のカラムを説明変数に代入する

# %%
trainX = train[['year', 'month', 'fun', 'temperature']]
testX = test[['year', 'month', 'fun', 'temperature']]

# %% [markdown]
# ## モデルの準備

# %% [markdown]
# モデルを表す変数を用意する

# %%
model2 = LR()

# %% [markdown]
# ## モデルの作成
#
# ### fit関数でモデルを作成する
#
# 説明変数、目的変数の順に指定

# %%
model2.fit(trainX, y)
# Out:
# LinearRegression()

# %% [markdown]
# モデルの傾きを確認する

# %%
model2.coef_
# Out:
# array([-76.3765687 ,  -4.20489757,  44.63348171,  -1.25463854])

# %% [markdown]
# モデルの切片を確認する

# %%
model2.intercept_
# Out:
# np.float64(153945.25411758255)

# %% [markdown]
# ## モデルを使った予測
#
# ### predict関数での予測

# %%
pred2 = model2.predict(testX)

# %% [markdown]
# ## モデルの評価
#
# ### SIGNATEで評価する形式にデータを加工する

# %% [markdown]
# sampleファイルのカラム[1]に、予測結果を代入する

# %%
sample[1] = pred2

# %%
sample.head()
# Out:
#            0          1
# 0  2014-10-1  55.452079
# 1  2014-10-2  50.809916
# 2  2014-10-3  44.787651
# 3  2014-10-6  53.821048
# 4  2014-10-7  53.068265

# %% [markdown]
# sampleをCSVファイルに書き出す

# %%
sample.to_csv('data/demand_forcast/output_submit4.csv', index=False, header=False)

# %% [markdown]
# 特徴量追加前後の予測値をグラフで比較する

# %%
pd.read_csv('data/demand_forcast/output_submit3.csv', header=None)[1].plot(label='sample')
pd.read_csv('data/demand_forcast/output_submit4.csv', header=None)[1].plot(label='submit2', color='red')
plt.legend()

# %% [markdown]
# 書き出したファイルを[SIGNATE](https://signate.jp/competitions/24/data)に投稿して評価を確認する
